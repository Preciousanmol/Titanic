# %% [markdown]
# # Read Import Liabraries

# %%
import numpy as np

import pandas as pd
import seaborn as sns
import matplotlib.ticker as mtick # For specifying the axes tick format 
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Machine Learning Liabraries

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.model_selection import cross_val_predict
from sklearn.metrics import confusion_matrix
from sklearn.metrics import precision_score, recall_score
from sklearn.metrics import f1_score

# %% [markdown]
# # Read .csv file

# %%
train=pd.read_csv('F:/kaggle//titanic/train.csv')
test=pd.read_csv('F:/kaggle//titanic/test.csv')
sub=pd.read_csv('F:/kaggle//titanic/gender_submission.csv')
test.head()
sub
# Out:
#      PassengerId  Survived
# 0            892         0
# 1            893         1
# 2            894         0
# 3            895         0
# 4            896         1
# 5            897         0
# 6            898         1
# 7            899         0
# 8            900         1
# 9            901         0
# 10           902         0
# 11           903         0
# 12           904         1
# 13           905         0
# 14           906         1
# 15           907         1
# 16           908         0
# 17           909         0
# 18           910         1
# 19           911         1
# 20           912         0
# 21           913         0
# 22           914         1
# 23           915         0
# 24           916         1
# 25           917         0
# 26           918         1
# 27           919         0
# 28           920         0
# 29           921         0
# ..           ...       ...
# 388         1280         0
# 389         1281         0
# ...

# %% [markdown]
# # Merge the test and train.csv files

# %%
f_test=pd.merge(sub,test ,on='PassengerId', how='inner')
f_test
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# 5            897         0       3
# 6            898         1       3
# 7            899         0       2
# 8            900         1       3
# 9            901         0       3
# 10           902         0       3
# 11           903         0       1
# 12           904         1       1
# 13           905         0       2
# 14           906         1       1
# 15           907         1       2
# 16           908         0       2
# 17           909         0       3
# 18           910         1       3
# 19           911         1       3
# 20           912         0       1
# 21           913         0       3
# 22           914         1       1
# 23           915         0       1
# 24           916         1       1
# ...

# %%
df=pd.concat([train,f_test]).reset_index(drop=True)
df
# Out:
#       PassengerId  Survived  Pclass  \
# 0               1         0       3
# 1               2         1       1
# 2               3         1       3
# 3               4         1       1
# 4               5         0       3
# 5               6         0       3
# 6               7         0       1
# 7               8         0       3
# 8               9         1       3
# 9              10         1       2
# 10             11         1       3
# 11             12         1       1
# 12             13         0       3
# 13             14         0       3
# 14             15         0       3
# 15             16         1       2
# 16             17         0       3
# 17             18         1       2
# 18             19         0       3
# 19             20         1       3
# 20             21         0       2
# 21             22         1       2
# 22             23         1       3
# 23             24         1       1
# 24             25         0       3
# ...

# %% [markdown]
# # Checking the first 5 rows and columns

# %%
df.head()
df.tail()
# Out:
#       PassengerId  Survived  Pclass                          Name     Sex  \
# 1304         1305         0       3            Spector, Mr. Woolf    male
# 1305         1306         1       1  Oliva y Ocana, Dona. Fermina  female
# 1306         1307         0       3  Saether, Mr. Simon Sivertsen    male
# 1307         1308         0       3           Ware, Mr. Frederick    male
# 1308         1309         0       3      Peter, Master. Michael J    male
#
#        Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# 1304   NaN      0      0           A.5. 3236    8.0500   NaN        S
# 1305  39.0      0      0            PC 17758  108.9000  C105        C
# 1306  38.5      0      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 1307   NaN      0      0              359309    8.0500   NaN        S
# 1308   NaN      1      1                2668   22.3583   NaN        C

# %% [markdown]
# # Shape of dataset

# %%
df.shape#(1309, 12)
train.shape#(891, 12)
test.shape#(418, 11)
# Out:
# (418, 11)

# %% [markdown]
# # Checking if the data contains any NULL value

# %%
#train.isnull().sum()
#test.isnull().sum()
df.isnull().sum()
# Out:
# PassengerId       0
# Survived          0
# Pclass            0
# Name              0
# Sex               0
# Age             263
# SibSp             0
# Parch             0
# Ticket            0
# Fare              1
# Cabin          1014
# Embarked          2
# dtype: int64

# %% [markdown]
# # Decsribing the data

# %%
train.describe()
df.describe()
# Out:
#        PassengerId     Survived       Pclass          Age        SibSp  \
# count  1309.000000  1309.000000  1309.000000  1046.000000  1309.000000
# mean    655.000000     0.377387     2.294882    29.881138     0.498854
# std     378.020061     0.484918     0.837836    14.413493     1.041658
# min       1.000000     0.000000     1.000000     0.170000     0.000000
# 25%     328.000000     0.000000     2.000000    21.000000     0.000000
# 50%     655.000000     0.000000     3.000000    28.000000     0.000000
# 75%     982.000000     1.000000     3.000000    39.000000     1.000000
# max    1309.000000     1.000000     3.000000    80.000000     8.000000
#
#              Parch         Fare
# count  1309.000000  1308.000000
# mean      0.385027    33.295479
# std       0.865560    51.758668
# min       0.000000     0.000000
# 25%       0.000000     7.895800
# 50%       0.000000    14.454200
# 75%       0.000000    31.275000
# max       9.000000   512.329200

# %% [markdown]
# # Taking out the information from the given data

# %%
df.info()
#df.columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 12 columns):
# PassengerId    1309 non-null int64
# Survived       1309 non-null int64
# Pclass         1309 non-null int64
# Name           1309 non-null object
# Sex            1309 non-null object
# Age            1046 non-null float64
# SibSp          1309 non-null int64
# Parch          1309 non-null int64
# Ticket         1309 non-null object
# Fare           1308 non-null float64
# Cabin          295 non-null object
# Embarked       1307 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 122.8+ KB

# %% [markdown]
# # Visulization of datset

# %%
df['Age'].hist()
plt.xlabel("AGE")
plt.ylabel("number of persons")
plt.show()

# %%
df.hist(figsize=(10,8))
plt.show()

# %%
sns.countplot(df["Survived"],label="Count")
figsize=(10,8)
plt.show()

# %%
plt.scatter(df['Age'],df['Survived'])
plt.xlabel("Age")
plt.ylabel("Survived")
plt.show()

# %%
plt.figure(figsize=(10,8))
sns.heatmap(df.corr(),linewidths=0.1,linecolor='black',square=True,cmap='summer')


plt.show()

# %%
player_features = (   "Survived",'Sex', 'Age', 'SibSp','Parch',  'Fare',  'Embarked')

from math import pi
idx = 1
plt.figure(figsize=(15,45))
for position_name, features in df.groupby(df['Pclass'])[player_features].mean().iterrows():
    top_features = dict(features.nlargest(5))
    
    # number of variable
    categories=top_features.keys()
    N = len(categories)

    # We are going to plot the first line of the data frame.
    # But we need to repeat the first value to close the circular graph:
    values = list(top_features.values())
    values += values[:1]

    # What will be the angle of each axis in the plot? (we divide the plot / number of variable)
    angles = [n / float(N) * 2 * pi for n in range(N)]
    angles += angles[:1]

    # Initialise the spider plot
    ax = plt.subplot(10, 3, idx, polar=True)

    # Draw one axe per variable + add labels labels yet
    plt.xticks(angles[:-1], categories, color='grey', size=8)
 # Draw ylabels
    #ax.set_rlabel_position(0)
    plt.yticks([25,50,75], ["25","50","75"], color="grey", size=7)
    plt.ylim(0,100)
    
    plt.subplots_adjust(hspace = 0.5)
    
    # Plot data
    ax.plot(angles, values, linewidth=1, linestyle='solid')

    # Fill area
    ax.fill(angles, values, 'b', alpha=0.1)
    
    plt.title(position_name, size=11, y=1.1)
    
    idx += 1
plt.show()
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
titanic = players = df[[   'Name','Pclass','Age',  'Fare',  'SibSp','Sex','Ticket', 'Cabin', 'Embarked','Survived']]

titanic.head()
# Out:
#                                                 Name  Pclass   Age     Fare  \
# 0                            Braund, Mr. Owen Harris       3  22.0   7.2500
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...       1  38.0  71.2833
# 2                             Heikkinen, Miss. Laina       3  26.0   7.9250
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)       1  35.0  53.1000
# 4                           Allen, Mr. William Henry       3  35.0   8.0500
#
#    SibSp     Sex            Ticket Cabin Embarked  Survived
# 0      1    male         A/5 21171   NaN        S         0
# 1      1  female          PC 17599   C85        C         1
# 2      0  female  STON/O2. 3101282   NaN        S         1
# 3      1  female            113803  C123        S         1
# 4      0    male            373450   NaN        S         0

# %%
import requests
import random
from math import pi

#import matplotlib.image as mpimg
#from matplotlib.offsetbox import (OffsetImage,AnnotationBbox)

def details(row, title,  age,ticket,gender, club,cabin,embarked,sibsp,survived):
    

        
    r = lambda: random.randint(0,255)
    colorRandom = '#%02X%02X%02X' % (r(),r(),r())
    
    if colorRandom == '#ffffff':colorRandom = '#a5d6a7'
    
    basic_color = '#37474f'
    color_annotate = '#01579b'
    
    #img = mpimg.imread(flag_image)
    
    plt.figure(figsize=(15,8))
    categories=list(titanic)[1:]
    coulumnDontUseGraph = ['SibSp','Sex','Ticket','Cabin','Embarked','Survived']
    N = len(categories) - len(coulumnDontUseGraph)
    
    angles = [n / float(N) * 2 * pi for n in range(N)]
    angles += angles[:1]
    
    ax = plt.subplot(111, projection='polar')
    ax.set_theta_offset(pi / 2)
    ax.set_theta_direction(-1)
    plt.xticks(angles[:-1], categories, color='Black', size=10)
    ax.set_rlabel_position(0)
    plt.yticks([10,30,50], ["10","30","50"], color="grey", size=10)
    plt.ylim(0,80)
    
    values = titanic.loc[row].drop('Name').values.flatten().tolist() 
    valuesDontUseGraph = [  sibsp,gender,ticket,cabin,embarked,survived]
    values = [e for e in values if e not in (valuesDontUseGraph)]
    values += values[:1]
    
    ax.plot(angles, values, color= basic_color, linewidth=1, linestyle='solid')
    ax.fill(angles, values, color= colorRandom, alpha=0.5)
    
    
    ax.annotate('Ticket: ' + ticket.upper(), xy=(10,10), xytext=(103, 138),
                fontsize= 12,
                color = 'white',
                bbox={'facecolor': color_annotate, 'pad': 7})
    
    ax.annotate('Sex: ' + gender.upper(), xy=(10,10), xytext=(70, 140),
                fontsize= 12,
                color = 'white',
                bbox={'facecolor': color_annotate, 'pad': 7})
    
    ax.annotate('Survived: ' +str(survived), xy=(10,10), xytext=(56, 170),
                fontsize= 12,
                color = 'white',
                bbox={'facecolor': color_annotate, 'pad': 7})
                      
                      
    ax.annotate('Age: ' + str(age), xy=(10,10), xytext=(43, 180),
                fontsize= 15,
                color = 'white',
                bbox={'facecolor': color_annotate, 'pad': 7})
    
    ax.annotate('Pclass: ' + str(club), xy=(10,10), xytext=(92, 168),
                fontsize= 12,
                color = 'white',
                bbox={'facecolor': color_annotate, 'pad': 7})
    plt.title(title, size=20, color= basic_color)

# %%
# defining a polar graph

def graphPolar(id = 0):
    if 0 <= id < len(df.PassengerId):
        details(row = titanic.index[id], 
                title = titanic['Name'][id], 
                age = titanic['Age'][id],
                ticket=titanic['Ticket'][id],
                gender=titanic['Sex'][id],
                cabin=titanic['Cabin'][id],
                embarked=titanic['Embarked'][id],
                sibsp=titanic['SibSp'][id],
                survived=titanic['Survived'][id],
                
                club =titanic['Pclass'][id])
    else:
        print('The base has 17917 players. You can put positive numbers from 0 to 17917')

# %%
graphPolar(0) 
plt.show()

# %%
dv=df["Survived"]

iv=df.drop(["PassengerId","Survived","Name","Ticket","Cabin"], axis=1)
iv.head()
#dv
# Out:
#    Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 0       3    male  22.0      1      0   7.2500        S
# 1       1  female  38.0      1      0  71.2833        C
# 2       3  female  26.0      0      0   7.9250        S
# 3       1  female  35.0      1      0  53.1000        S
# 4       3    male  35.0      0      0   8.0500        S

# %%
from sklearn.preprocessing import LabelEncoder
X_labelencoder = LabelEncoder()
iv.iloc[:, 1] = X_labelencoder.fit_transform(iv.iloc[:, 1].astype(str))
iv.iloc[:, 6] = X_labelencoder.fit_transform(iv.iloc[:, 6].astype(str))
iv.head()
# Out:
#    Pclass  Sex  Age  SibSp  Parch     Fare  Embarked
# 0       3    1   25      1      0   7.2500         2
# 1       1    0   51      1      0  71.2833         0
# 2       3    0   32      0      0   7.9250         2
# 3       1    0   47      1      0  53.1000         2
# 4       3    1   47      0      0   8.0500         2

# %%
from sklearn.preprocessing import Imputer
# First create an Imputer , Stratergy means what we want to write in place of missed value
missingValueImputer = Imputer (missing_values = 'NaN', strategy = 'mean', axis = 0)  #if missing values are represented by 9999 then write same here
# Set which columns imputer should perform

missingValueImputer = missingValueImputer.fit (iv[['Age']])
# update values of X with new values
iv[['Age']] = missingValueImputer.transform(iv[['Age']])

# Set which columns imputer should perform

iv[['Fare']] = missingValueImputer.fit_transform(iv[['Fare']])
iv.head()
iv.head()
# Out:
#    Pclass  Sex   Age  SibSp  Parch     Fare  Embarked
# 0       3    1  25.0      1      0   7.2500         2
# 1       1    0  51.0      1      0  71.2833         0
# 2       3    0  32.0      0      0   7.9250         2
# 3       1    0  47.0      1      0  53.1000         2
# 4       3    1  47.0      0      0   8.0500         2

# %%
X_train=iv[:891]
X_test=iv[891:]
y_train=dv[:891]
y_test=dv[891:]

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()
model.fit(X_train, y_train)
predictions = model.predict(X_test)
predictions 
sub['Prediction']=pd.Series(predictions)
sub.to_csv('F:/kaggle//titanic/predlogistic.csv')

# %%
from sklearn.metrics import accuracy_score

print("Accuracy is",accuracy_score(y_test, predictions))
# Out:
# Accuracy is 0.968899521531

# %%
#logistic regression with PCA

# %%
from sklearn.preprocessing import MinMaxScaler
mms= MinMaxScaler()
scaledX_train= mms.fit_transform(X_train)
scaledX_test=mms.transform(X_test)
model.fit(scaledX_train, y_train)
predictions = model.predict(scaledX_test)
predictions 
sub['Prediction']=pd.Series(predictions)
sub.to_csv('F:/kaggle//titanic/predminmaxlogistic.csv')

# %%
from sklearn.decomposition import PCA
pca=PCA(n_components=3)
analyzedX_train= pca.fit_transform(scaledX_train)
analyzedX_test= pca.transform(scaledX_test)
plt.plot(pca.explained_variance_ratio_)
plt.show()

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()
model.fit(analyzedX_train, y_train)
predictions = model.predict(analyzedX_test)
predictions 
sub['Prediction']=pd.Series(predictions)
#sub.to_csv('F:/kaggle//titanic/predlogisticpca.csv')

# %%
from sklearn.metrics import accuracy_score

print("Accuracy is",accuracy_score(y_test, predictions))
# Out:
# Accuracy is 0.995215311005

# %%
#random forest clasifer

# %%
from sklearn.ensemble import RandomForestClassifier
modelrandom = RandomForestClassifier(random_state=8, max_depth=3)

modelrandom.fit(X_train, y_train)
pred=modelrandom.predict(X_test)
pred
from sklearn.metrics import accuracy_score


print("Accuracy is",accuracy_score(y_test, pred))
pred
sub['Prediction']=pd.Series(pred)
sub
#sub.to_csv('F:/kaggle//titanic/predrandom.csv')
# Out:
# Accuracy is 0.956937799043
#      PassengerId  Survived  Prediction
# 0            892         0           0
# 1            893         1           0
# 2            894         0           0
# 3            895         0           0
# 4            896         1           0
# 5            897         0           0
# 6            898         1           1
# 7            899         0           0
# 8            900         1           1
# 9            901         0           0
# 10           902         0           0
# 11           903         0           0
# 12           904         1           1
# 13           905         0           0
# 14           906         1           1
# 15           907         1           1
# 16           908         0           0
# 17           909         0           0
# 18           910         1           0
# 19           911         1           1
# 20           912         0           0
# 21           913         0           0
# ...

# %%
#Random forest with min max
modelrandom.fit(scaledX_train, y_train)
pred=modelrandom.predict(scaledX_test)
pred
from sklearn.metrics import accuracy_score
print("Accuracy is",accuracy_score(y_test, pred))
pred
sub['Prediction']=pd.Series(pred)
sub
#sub.to_csv('F:/kaggle//titanic/predminmaxrandom.csv')
# Out:
# Accuracy is 0.956937799043
#      PassengerId  Survived  Prediction
# 0            892         0           0
# 1            893         1           0
# 2            894         0           0
# 3            895         0           0
# 4            896         1           0
# 5            897         0           0
# 6            898         1           1
# 7            899         0           0
# 8            900         1           1
# 9            901         0           0
# 10           902         0           0
# 11           903         0           0
# 12           904         1           1
# 13           905         0           0
# 14           906         1           1
# 15           907         1           1
# 16           908         0           0
# 17           909         0           0
# 18           910         1           0
# 19           911         1           1
# 20           912         0           0
# 21           913         0           0
# ...

# %%
#Random forest with PCA
modelrandom.fit(analyzedX_train, y_train)
pred=modelrandom.predict(analyzedX_test)
pred
from sklearn.metrics import accuracy_score


print("Accuracy is",accuracy_score(y_test, pred))
pred
sub['Prediction']=pd.Series(pred)
sub
#sub.to_csv('F:/kaggle//titanic/predpcarandom.csv')
# Out:
# Accuracy is 0.892344497608
#      PassengerId  Survived  Prediction
# 0            892         0           0
# 1            893         1           0
# 2            894         0           0
# 3            895         0           0
# 4            896         1           1
# 5            897         0           0
# 6            898         1           0
# 7            899         0           0
# 8            900         1           0
# 9            901         0           0
# 10           902         0           0
# 11           903         0           0
# 12           904         1           1
# 13           905         0           0
# 14           906         1           1
# 15           907         1           1
# 16           908         0           0
# 17           909         0           0
# 18           910         1           0
# 19           911         1           0
# 20           912         0           0
# 21           913         0           0
# ...

# %%
#naive bayes clasifier

# %%
#GaussianNB is specifically used when the features have continuous values.

from sklearn.naive_bayes import GaussianNB
model = GaussianNB()
model.fit(X_train, y_train)

prediction = model.predict(X_test)


from sklearn.metrics import accuracy_score

print(accuracy_score(y_test, prediction))

prediction
#df['three']=pd.Series([10,20,30],index=['a','b','c'])
sub['Prediction']=pd.Series(prediction)
sub

#sub.to_csv('F:/kaggle//titanic/predgaussian.csv')
# Out:
# 0.8995215311
#      PassengerId  Survived  Prediction
# 0            892         0           0
# 1            893         1           1
# 2            894         0           0
# 3            895         0           0
# 4            896         1           1
# 5            897         0           0
# 6            898         1           1
# 7            899         0           0
# 8            900         1           1
# 9            901         0           0
# 10           902         0           0
# 11           903         0           0
# 12           904         1           1
# 13           905         0           0
# 14           906         1           1
# 15           907         1           1
# 16           908         0           0
# 17           909         0           0
# 18           910         1           1
# 19           911         1           1
# 20           912         0           1
# 21           913         0           0
# 22           914         1           1
# ...

# %%
#Gaussian with min max
model.fit(scaledX_train, y_train)
pred=model.predict(scaledX_test)
pred
from sklearn.metrics import accuracy_score
print("Accuracy is",accuracy_score(y_test, pred))
pred
sub['Prediction']=pd.Series(pred)
sub
#sub.to_csv('F:/kaggle//titanic/predminmaxgaussian.csv')
# Out:
# Accuracy is 0.8995215311
#      PassengerId  Survived  Prediction
# 0            892         0           0
# 1            893         1           1
# 2            894         0           0
# 3            895         0           0
# 4            896         1           1
# 5            897         0           0
# 6            898         1           1
# 7            899         0           0
# 8            900         1           1
# 9            901         0           0
# 10           902         0           0
# 11           903         0           0
# 12           904         1           1
# 13           905         0           0
# 14           906         1           1
# 15           907         1           1
# 16           908         0           0
# 17           909         0           0
# 18           910         1           1
# 19           911         1           1
# 20           912         0           1
# 21           913         0           0
# ...

# %%
model.fit(analyzedX_train,y_train)

prediction = model.predict(analyzedX_test)

from sklearn.metrics import accuracy_score

print(accuracy_score(y_test, prediction))

prediction
#df['three']=pd.Series([10,20,30],index=['a','b','c'])
sub['Prediction']=pd.Series(prediction)
sub

#sub.to_csv('F:/kaggle//titanic/predpcagaussian.csv')
# Out:
# 1.0
#      PassengerId  Survived  Prediction
# 0            892         0           0
# 1            893         1           1
# 2            894         0           0
# 3            895         0           0
# 4            896         1           1
# 5            897         0           0
# 6            898         1           1
# 7            899         0           0
# 8            900         1           1
# 9            901         0           0
# 10           902         0           0
# 11           903         0           0
# 12           904         1           1
# 13           905         0           0
# 14           906         1           1
# 15           907         1           1
# 16           908         0           0
# 17           909         0           0
# 18           910         1           1
# 19           911         1           1
# 20           912         0           0
# 21           913         0           0
# 22           914         1           1
# ...

# %%
from sklearn.tree import DecisionTreeClassifier
#decision_tree = DecisionTreeClassifier(criterion = "gini", max_depth = 3,random_state = 100)
#decision_tree.fit(X_train, y_train)
decision_tree = DecisionTreeClassifier(criterion = "entropy", random_state = 100,max_depth=3)
decision_tree.fit(X_train, y_train)
predictValues =decision_tree.predict(X_test)

predictValues
from sklearn.metrics import accuracy_score


print("Accuracy is",accuracy_score(y_test, predictValues))
pred
sub['Prediction']=pd.Series(predictValues)
sub
#sub.to_csv('F:/kaggle//titanic/preddesion.csv')
# Out:
# Accuracy is 0.985645933014
#      PassengerId  Survived  Prediction
# 0            892         0           0
# 1            893         1           1
# 2            894         0           0
# 3            895         0           0
# 4            896         1           1
# 5            897         0           0
# 6            898         1           1
# 7            899         0           0
# 8            900         1           1
# 9            901         0           0
# 10           902         0           0
# 11           903         0           0
# 12           904         1           1
# 13           905         0           0
# 14           906         1           1
# 15           907         1           1
# 16           908         0           0
# 17           909         0           0
# 18           910         1           1
# 19           911         1           1
# 20           912         0           0
# 21           913         0           0
# ...

# %%
#Gaussian with min max
decision_tree.fit(scaledX_train, y_train)
pred=decision_tree.predict(scaledX_test)
pred
from sklearn.metrics import accuracy_score
print("Accuracy is",accuracy_score(y_test, pred))
pred
sub['Prediction']=pd.Series(pred)
sub
sub.to_csv('F:/kaggle//titanic/predminmaxdesion.csv')
# Out:
# Accuracy is 0.985645933014

# %%
decision_tree.fit(analyzedX_train,y_train)

prediction =decision_tree.predict(analyzedX_test)

from sklearn.metrics import accuracy_score

print(accuracy_score(y_test, prediction))

prediction
#df['three']=pd.Series([10,20,30],index=['a','b','c'])
sub['Prediction']=pd.Series(prediction)
sub

sub.to_csv('F:/kaggle//titanic/predpcadesion.csv')

# %%
data_feature_names = [ 'Pclass','Sex','Age','SibSp','Parch','Fare','Embarked']

from sklearn.tree import export_graphviz
from sklearn import tree
from graphviz import Source
from IPython.display import SVG
from IPython.display import display

graph = Source(tree.export_graphviz(decision_tree, out_file=None
   , feature_names=data_feature_names
   , filled = True,rounded=True))


display(SVG(graph.pipe(format='svg')))
